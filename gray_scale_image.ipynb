# %%
import imageio
import matplotlib.pyplot as plt
import numpy as np

# %%
photo_data = imageio.imread("tulip.jpg")
plt.figure(figsize=(15,15))
plt.imshow(photo_data)

# %%
photo_data = imageio.imread("tulip.jpg")
rows,cols,layers = photo_data.shape
print(rows, cols, layers)

for x in range(rows):
    for y in range(cols):
        photo_data[x,y] = photo_data[x,y].mean()

print(photo_data[500,450])

plt.figure(figsize=(15,15))
plt.imshow(photo_data)
# Out:
# 600 600 3
